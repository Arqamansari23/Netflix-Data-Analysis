# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("8. Netflix Dataset.xlsx")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                     0.03
# 1         s2    Movie                                 07:19:00
# 2         s3    Movie                                 23:59:00
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...
# ...

# %% [markdown]
# # Some basic information about the daatset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.shape      # to show number of rows and number of colums
# Out:
# (7789, 11)

# %%
df.size   # total numbers of element in dataset
# Out:
# 85679

# %%
df.columns    # Names Of all colums
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      Show_Id Category                                    Title  \
# 0         s1  TV Show                                     0.03
# 1         s2    Movie                                 07:19:00
# 2         s3    Movie                                 23:59:00
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...
# ...

# %% [markdown]
# # If any duplicate values in dataset , if any remove them

# %%
df[df.duplicated()]   # total numbers of duplicate values
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#              Release_Date Rating Duration  \
# 6300  2019-04-05 00:00:00  TV-MA   97 min
# 6622  2020-09-04 00:00:00  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df=df.drop_duplicates()

# %%
df[df.duplicated()]    # no duplicate left
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# # if there is any null values present in dataset show by data frame and by heat map

# %%
df.isna().sum()   # shows all the numeric values in data frame
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(df.isna())  # show the null values by heat map
# Out:
# <Axes: >

# %%
df=df.dropna(how='any')

# %%
df.isna().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %% [markdown]
# #  Q1 For 'House of Cards ' what is the show id and whow is the director of the movie

# %% [markdown]
# # # isin()

# %%
df[df['Title'].isin(['House of Cards'])][['Show_Id','Director']]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# ## str.contains()

# %%
#df[df['Title'].str.contains('House of Cards')]

# %% [markdown]
# # In which year Highest number of Movies Released show With bar graph

# %% [markdown]
# # # change  date time datatype

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df['Release_Date']=pd.to_datetime(df['Release_Date'])

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %%
df['Release_Date'].dt.year.value_counts()   # in 2019 most  movies relese
# Out:
# 2019    1337
# 2020    1229
# 2018    1115
# 2017     752
# 2016     207
# 2021      78
# 2015      50
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2010       1
# 2008       1
# Name: Release_Date, dtype: int64

# %%
df['Release_Date'].dt.year.value_counts().plot(kind='bar')   # bar graph
# Out:
# <Axes: >

# %% [markdown]
# # Q how many Movies And Tv shows are there in data set ?

# %%
df.groupby('Category').Category.count()  # number of movies and tv shows in data  set
# Out:
# Category
# Movie      4673
# TV Show     136
# Name: Category, dtype: int64

# %% [markdown]
# # Q Show All the Movies That are Released in 2000

# %%
df[(df['Category']=="Movie") & (df['Release_Date'].dt.year==2000)]   # no movie in the year 2020
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# # Q show all the tv series tha relesed in india only

# %%
df[(df['Category']=="TV Show") & (df['Country']=='India')]
# Out:
#      Show_Id Category                                  Title  \
# 132     s133  TV Show                              7 (Seven)
# 2406   s2407  TV Show                                  GHOUL
# 3119   s3120  TV Show           Jamtara - Sabka Number Ayega
# 4724   s4725  TV Show                        Paava Kadhaigal
# 6037   s6037  TV Show  Th Eena Meena Deeka Chase Comedy Show
#
#                                                Director  \
# 132                                         Nizar Shafi
# 2406                                     Patrick Graham
# 3119                                    Soumendra Padhi
# 4724  Sudha Kongara, Vignesh Shivan, Gautham Vasudev...
# 6037                                      Dheeraj Berry
#
#                                                    Cast Country Release_Date  \
# 132   Rahman, Havish, Regina Cassandra, Nandita Swet...   India   2019-07-30
# 2406  Radhika Apte, Manav Kaul, Ratnabali Bhattachar...   India   2018-08-24
# ...

# %% [markdown]
# # Q show top 10 directors who gave Highest number of Tv shows and movies

# %%
df['Director'].value_counts().head(10)
# Out:
# RaÃºl Campos, Jan Suter    18
# Marcus Raboy               15
# Jay Karas                  14
# Cathy Garcia-Molina        13
# Jay Chapman                12
# Youssef Chahine            12
# Martin Scorsese            12
# Steven Spielberg           10
# David Dhawan                9
# Robert Rodriguez            8
# Name: Director, dtype: int64

# %% [markdown]
# # Q Show all the movies Where category is 'Movie' Type is 'Comedy' or countrt is United States

# %%
 df[(df['Category']=="Movie") & (df['Type']=='Comedies') | (df['Country']=='United States')]
# Out:
#      Show_Id Category                       Title         Director  \
# 3         s4    Movie                           9      Shane Acker
# 4         s5    Movie                          21   Robert Luketic
# 7         s8    Movie                         187   Kevin Reynolds
# 10       s11    Movie                        1922     Zak Hilditch
# 14       s15    Movie                        3022       John Suits
# ...      ...      ...                         ...              ...
# 7760   s7759    Movie  Zack and Miri Make a Porno      Kevin Smith
# 7773   s7772    Movie                        Zion       Floyd Russ
# 7776   s7775    Movie                      Zodiac    David Fincher
# 7780   s7779    Movie                  Zombieland  Ruben Fleischer
# 7783   s7782    Movie                        Zoom     Peter Hewitt
#
#                                                    Cast        Country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %% [markdown]
# #  Q in How many Movies/ Tv shows Tom Cruise was casted ?

# %%
df[df['Cast']=='Tom Cruise']    # no result shown because there are mixed names
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df[df['Cast'].str.contains('Tom Cruise') ]   # give result when only one countains
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %% [markdown]
# #  Q what are the Different Rating asssigned by Netflix

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # Q how many movies got 'TV-14' raiting in canada

# %%
df[(df["Category"]=='Movie') & (df['Rating']=='TV-14') & (df['Country']=='Canada')].shape  # 9  movies
# Out:
# (9, 11)

# %% [markdown]
# #  Q How many Tv shows got the R raiting after 2018

# %%
df[(df['Category']=='Tv Show')  & (df['Rating']=='R')  & (df['Release_Date'].dt.year > 2018)]   # no such tv shows
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# #  Q what is the maximum duration of  Movie/Show in Netflix

# %%
df['Duration'].unique()  #ignore sesons
# Out:
# array(['93 min', '78 min', '80 min', '123 min', '1 Season', '95 min',
#        '119 min', '118 min', '143 min', '103 min', '89 min', '91 min',
#        '149 min', '144 min', '124 min', '110 min', '128 min', '117 min',
#        '100 min', '99 min', '102 min', '104 min', '105 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '87 min', '109 min',
#        '101 min', '90 min', '113 min', '114 min', '130 min', '94 min',
#        '140 min', '135 min', '82 min', '70 min', '92 min', '164 min',
#        '83 min', '116 min', '84 min', '86 min', '120 min', '96 min',
#        '126 min', '75 min', '129 min', '77 min', '137 min', '148 min',
#        '121 min', '122 min', '176 min', '85 min', '22 min', '68 min',
#        '111 min', '29 min', '142 min', '168 min', '59 min', '108 min',
#        '44 min', '26 min', '156 min', '98 min', '57 min', '150 min',
#        '133 min', '115 min', '154 min', '127 min', '146 min', '136 min',
# ...

# %%
df[['Minutes','Unit']]=df['Duration'].str.split(' ', expand=True)  # make seperate colums for minutes

# %%
df
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie    07:19:00  Jorge Michel Grau
# 2         s3    Movie    23:59:00       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
df['Minutes'].max()   # wrong because dtye in string
# Out:
# '99'

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Minutes                 object
# Unit                    object
# dtype: object

# %%
df['Minutes']=pd.to_numeric(df['Minutes'])

# %%
df['Minutes'].max()  # now right
# Out:
# 253

# %% [markdown]
# # Q which indivisual country has the highest number of tv shows

# %%
df[df['Category']=='TV Show']['Country'].value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# Taiwan                                                            6
# Turkey                                                            5
# India                                                             5
# Brazil                                                            4
# Canada                                                            3
# Thailand                                                          3
# Nigeria                                                           3
# France                                                            3
# China                                                             2
# ...

# %% [markdown]
# # Q How can we sort The data Frame by Year

# %%
df['year']=df['Release_Date'].dt.year

# %%
df
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie    07:19:00  Jorge Michel Grau
# 2         s3    Movie    23:59:00       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
df.sort_values(by='year', ascending=False)
# Out:
#      Show_Id Category                        Title  \
# 2269   s2270    Movie                   Fred Claus
# 2349   s2350    Movie                    Gangaajal
# 6248   s6248    Movie           The Creative Brain
# 1673   s1674    Movie                  Death of Me
# 7147   s7146    Movie  Tony Parker: The Final Shot
# ...      ...      ...                          ...
# 2041   s2042    Movie                Even the Rain
# 3840   s3841    Movie  Mad Ron's Prevues from Hell
# 3248   s3249    Movie      Just Another Love Story
# 5766   s5766    Movie                     Splatter
# 7115   s7114    Movie         To and From New York
#
#                              Director  \
# 2269                     David Dobkin
# 2349                      Prakash Jha
# 6248  Jennifer Beamish, Toby Trackman
# 1673              Darren Lynn Bousman
# 7147                    Florent Bodin
# ...                               ...
# 2041                  IcÃ­ar BollaÃ­n
# ...
